# %% [markdown]
# <b>Scraping and Analyzing Fed Beige Books</b><br>
# Project by Alexander Trentin<br>

# %% [markdown]
# <b>General overview</b>:
# The Fed Beige Book is a collection of economic observations and assessments by the Federal Reserve Bank published eight times a year. They provide for each of the twelve districts of the Federal Reserve System and the national level an anecdotal overview of the current economic climate. The different districts provide observations for the whole economy, prices and wages, and individual sectors.<p>
# The documents can be found here:
# https://www.federalreserve.gov/monetarypolicy/beige-book-default.htm

# %% [markdown]
# <b>Central purpose of this project:</b><br>
# Make a massive corpus of free text with valuable economic observations easily accessible.<p>
# <b>Idea:</b><br>
# 1. Extract from each assessment an "important phrase" to summarize the longer text
# 2. Provide a quantitative score to show if the economic assessment is positive, negative or neutral.

# %% [markdown]
# Part 1: Scraping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import os

# %%
# Manually the dates of the reports to be collected are defined in a list.
# This is necessary to open the right documents.
# Overview: https://www.federalreserve.gov/monetarypolicy/beige-book-archive.htm
# The Fed Beige Books are HTML documents, separated by the Federal Reserve district and date.

# List of dates (month) when reports were published.

# During the collection process it was observed,
# that the report of "2015-07" was not published in the archive as it was supposed to be.
# Subsequently, this date was deleted from the list.

report_dates = [
"2008-01",
"2008-03",
"2008-04",
"2008-06",
"2008-07",
"2008-09",
"2008-10",
"2008-12",
"2009-01",
"2009-03",
"2009-04",
"2009-06",
"2009-07",
"2009-09",
"2009-10",
"2009-12",
"2010-01",
"2010-03",
"2010-04",
"2010-06",
"2010-07",
"2010-09",
"2010-10",
"2010-12",
"2011-01",
"2011-03",
"2011-04",
"2011-06",
"2011-07",
"2011-09",
"2011-10",
"2011-11",
"2012-01",
"2012-02",
"2012-04",
"2012-06",
"2012-07",
"2012-08",
"2012-10",
"2012-11",
"2013-01",
"2013-03",
"2013-04",
"2013-06",
"2013-07",
"2013-09",
"2013-10",
"2013-12",
"2014-01",
"2014-03",
"2014-04",
"2014-06",
"2014-07",
"2014-09",
"2014-10",
"2014-12",
"2015-01",
"2015-03",
"2015-04",
"2015-06",
"2015-09",
"2015-10",
"2015-12",
"2016-01",
"2016-03",
"2016-04",
"2016-06",
"2016-07",
"2016-09",
"2016-10",
"2016-11",
"2017-01",
"2017-03",
"2017-04",
"2017-05",
"2017-07"
]

report_update_dates = [
    "2017-07"
]

# %%
# which districts
report_districts = {
    "su":"National Summary",
    "at":"Atlanta",
    "bo":"Boston",
    "ch":"Chicago",
    "cl":"Cleveland",
    "da":"Dallas",
    "kc":"Kansas City",
    "mi":"Minneapolis",
    "ny":"New York",
    "ph":"Philadelphia",
    "ri":"Richmond",
    "sf":"San Francisco",
    "sl":"St Louis"
}

# %%
#collect all HTML documents
#save them locally (989 files)

for this_date in report_update_dates: 
    
    for this_district in report_districts.keys():
        this_URL = "https://www.minneapolisfed.org/news-and-events/beige-book-archive/"\
            +this_date+"-"+this_district
        
        district_description = report_districts[this_district]
        
        response = requests.get(this_URL)
        
        path = os.getcwd()+"/HTML/"+this_date+"_"+district_description+".html"
        
        with open(path, 'w') as f : f.write(response.text)

# %%
# Open HTML files, each one as a Beautiful Soup docs
# All Beautiful Soup documents are stored in one dictionary doc_dict
# The dictionary has the keys "date" and as value a sub-dictionary
# This sub-dictionary has as keys the district and as values the Beautiful Soup doc. 

doc_dict = {}

for this_date in report_dates:
    
    this_date_formatted = this_date[:4]+this_date[5:]
    
    doc_dict[this_date_formatted] = {}
    
    for this_district in report_districts.keys():
        
        district_description = report_districts[this_district]
        
        path = os.getcwd()+"/HTML/"+this_date+"_"+district_description+".html"
        
        this_html = open(path)
        
        this_doc = BeautifulSoup(this_html, 'html.parser')
            
        # only the section "article-content" is relevant
        
        this_doc = this_doc.find("section", {"class" : "article-content"})
        doc_dict[this_date_formatted][district_description] = this_doc

# %%
#Dictionary storing texts for each of the sectors
#Like the dictionary with Beautiful Soup docs, this one will store the scraped descriptions
#The dictionary texts_dic has as keys the dates and as values sub-dictionaries
#Each sub-dictionary has as keys the district name and as values the description as a string

texts_dict = {}

for this_date in doc_dict.keys():
    
    texts_dict[this_date] = {}
    
    for this_district in doc_dict[this_date].keys():
        this_doc = doc_dict[this_date][this_district]
        
        texts_dict[this_date][this_district] = {}
        
        observ = texts_dict[this_date][this_district]
        
        # National Summaries have a specific format
        # there are two different formats:
        # one where the first section is titled as "Overall Economic Activity"
        # and the older format where there is no title
        
        #starting from July 2009, there was a new paragraph
        if int(this_date) > 200906 and this_district == "National Summary":
            this_html = this_doc.find(text=re.compile('.repar.')).find_next()
                
        else:
            this_html = this_doc.find_all("strong")[0].find_next("p")
            
        # new format with a new title starting in 2017
        if int(this_date) < 201701:
            this_sector= 'Overall Economic Activity'
            this_string = this_html.text.strip()
                        
        else:
            while this_html.find("strong") is None and this_html.find("em") is None:
                this_html = this_html.find_next()

            
            this_html = this_html.find("strong")
            
            this_sector = this_html.text.strip()
            
            
            while this_sector == "":
                this_html = this_html.find_next()
                if this_html.find("strong"):
                    this_html = this_html.find("strong")
                    this_sector = this_html.text.strip()
                    
            if this_html.next_sibling:
                if this_html.next_sibling.name == "br":
                    this_string = this_html.next_sibling.next_sibling
                else:
                    this_string = this_html.next_sibling
            
        observ[this_sector] = this_string
             
        this_html = this_html.find_next()
    
            
        while this_html and this_html.find("strong") is None and this_html.find("em") is None:
            this_string = this_html.text.strip()
            observ[this_sector] =\
                observ[this_sector]+"\n"+this_string
            this_html = this_html.find_next()
        
        # check the other sectors
        
                        
        # find the header (sector) by formatting "strong"
            
        while this_html and this_html.find("div") is None and this_html.find("em") is None:
        
            this_html = this_html.find("strong")
                
            this_sector = this_html.text.strip()
            
            counter = 0
            while this_sector == "" or this_sector == ".":
                counter += 1
                this_html = this_html.find_next()
                if this_html.find("strong") and this_html.find("strong").name !="br":
                    this_html = this_html.find("strong")
                    this_sector = this_html.text.strip()
                if counter>2:
                    break
                    
            if this_html.find_next().name == "strong":
                    this_html = this_html.find_next()
                    this_sector = this_sector + " " + this_html.text.strip()
                
            if this_sector == "":
                print(this_date,this_district)
                    
            #Since beginning of 2017, highlights for each district are shown in the
            #summary. They should not be included.
            
            check_year = int(this_date) > 201612 and this_district == 'National Summary'
            check_highlights = False
            
            #the non-strong part should be part of the string
            
            if this_html.next_sibling:
                if this_html.next_sibling.name == "br":
                            if this_html.next_sibling.next_sibling.name == "strong":
                                this_sector = this_sector + " " + this_html.text.strip()
                                this_html = this_html.next_sibling.next_sibling

            observ[this_sector] = ""
            this_string = ""
            
            while this_html.next_sibling:
                if this_html.next_sibling.name == "br":
                    if this_html.next_sibling.next_sibling.name != "strong":
                        this_html = this_html.next_sibling.next_sibling
                    else:
                        if this_html.next_sibling.next_sibling:
                            this_html = this_html.next_sibling.next_sibling
                else:
                    this_html = this_html.next_sibling
                if isinstance(this_html,str):
                    this_string = this_html.strip()
                    observ[this_sector] =\
                        observ[this_sector]+"\n"+this_string

            this_html = this_html.find_next()
        
            while this_html.find("div") is None and this_html.find("em") is None:
                if this_html.find("strong"):
                    if this_html.find("strong").text.strip():
                        break
                        
                this_string = this_html.text.strip()
                
                #check if the description arrived at "Highlights by Federal Reserve District"
                if check_year and re.search('Highlights by.',this_string):
                    check_highlights = True
                    break
                    
                observ[this_sector] =\
                    observ[this_sector]+"\n"+this_string
                this_html = this_html.find_next() 
                
            if check_highlights:
                    break

# %%
#cleaning up keys
#there are some special characters in some sector names

sectors = []

for date in texts_dict.keys():
    for district in texts_dict[date].keys():
        for sector in texts_dict[date][district].keys():
            sectorNew = sector.replace('  ',' ')
            texts_dict[date][district][sectorNew] = texts_dict[date][district].pop(sector)
            sector = sectorNew
            
            sectorNew = sector.replace('\xc2','')
            texts_dict[date][district][sectorNew] = texts_dict[date][district].pop(sector)
            sector = sectorNew
            
            sectorNew = sector.replace('.','')
            texts_dict[date][district][sectorNew] = texts_dict[date][district].pop(sector)
            sector = sectorNew
            sectors.append(sector)
            
#get a list of all used sector titles
sectors = set(sectors)

# %%
import csv

with open('sectors.csv', 'w') as myfile:
    wr = csv.writer(myfile, delimiter='\n', quoting=csv.QUOTE_ALL)
    wr.writerow(sectors)

# %% [markdown]
# # Mapping the sectors to 7 categories
# This is necessary as the different Fed districts use different sectors to break down their reports.<p>
#
# Agriculture, Energy, Natural Resources<br>
# Finance<br>
# Real Estate, Construction<br>
# Manufacturing, Services<br>
# Employment, Prices, Wages<br>
# Retail, Consumer Spending<br>
# Economy

# %%
# using self-created CSV file to map sectors to categories
# joining it with the dictionary in in Pandas
df_categories = pd.read_csv('mapping_sectors.csv', sep=';')

# %%
# The dictionary with sub-dictionaries are imported into Pandas to do the mapping

# The solution to get nested dictionary into Pandas is derived from stack overflow
#https://stackoverflow.com/questions/33611782/pandas-dataframe-from-nested-dictionary
df = pd.DataFrame([(k1,k2,k3,v3) for k1,v1 in texts_dict.items() \
                   for k2,v2 in v1.items()\
                   for k3,v3 in v2.items()],\
                   columns = ['Date','District','Sector','Description'])

df.sort_values(['Date','District','Sector']).head(5)

df[df.Date=='201510']
# Out:
#         Date          District                                       Sector  \
# 5813  201510  National Summary                Consumer Spending and Tourism
# 5814  201510  National Summary                 Employment, Wages and Prices
# 5815  201510  National Summary                    Overall Economic Activity
# 5816  201510  National Summary                        Nonfinancial Services
# 5817  201510  National Summary                                Manufacturing
# 5818  201510  National Summary                 Real Estate and Construction
# 5819  201510  National Summary            Agriculture and Natural Resources
# 5820  201510  National Summary               Banking and Financial Services
# 5821  201510           Atlanta                 Real Estate and Construction
# 5822  201510           Atlanta             Manufacturing and Transportation
# 5823  201510           Atlanta                          Banking and Finance
# 5824  201510           Atlanta                        Employment and Prices
# 5825  201510           Atlanta            Natural Resources and Agriculture
# 5826  201510           Atlanta                    Overall Economic Activity
# 5827  201510           Atlanta                Consumer Spending and Tourism
# 5828  201510            Boston           Manufacturing and Related Services
# 5829  201510            Boston                   Selected Business Services
# 5830  201510            Boston                      Residential Real Estate
# 5831  201510            Boston                    Overall Economic Activity
# 5832  201510            Boston                           Retail and Tourism
# 5833  201510            Boston                       Commercial Real Estate
# 5834  201510           Chicago                            Consumer Spending
# 5835  201510           Chicago                                  Agriculture
# 5836  201510           Chicago                    Overall Economic Activity
# 5837  201510           Chicago                            Business Spending
# 5838  201510           Chicago                 Construction and Real Estate
# 5839  201510           Chicago                                Manufacturing
# 5840  201510           Chicago                             Prices and Costs
# 5841  201510           Chicago                          Banking and Finance
# 5842  201510         Cleveland                 Real Estate and Construction
# ...      ...               ...                                          ...
# 5879  201510          New York                      Other Business Activity
# 5880  201510      Philadelphia                                       Retail
# 5881  201510      Philadelphia                                      Finance
# 5882  201510      Philadelphia                 Real Estate and Construction
# 5883  201510      Philadelphia                                     Services
# 5884  201510      Philadelphia                             Prices and Wages
# 5885  201510      Philadelphia                    Overall Economic Activity
# 5886  201510      Philadelphia                                Manufacturing
# 5887  201510          Richmond                                Manufacturing
# 5888  201510          Richmond                                  Real Estate
# 5889  201510          Richmond            Agriculture and Natural Resources
# 5890  201510          Richmond                                        Labor
# 5891  201510          Richmond                    Overall Economic Activity
# 5892  201510          Richmond                                       Retail
# 5893  201510          Richmond                                     Services
# 5894  201510          Richmond                                      Finance
# 5895  201510          Richmond                                        Ports
# 5896  201510     San Francisco                    Retail Trade and Services
# 5897  201510     San Francisco                                Manufacturing
# 5898  201510     San Francisco  Agriculture and Resource-Related Industries
# 5899  201510     San Francisco                 Real Estate and Construction
# 5900  201510     San Francisco                       Financial Institutions
# 5901  201510     San Francisco                    Overall Economic Activity
# 5902  201510     San Francisco                             Prices and Wages
# 5903  201510          St Louis    Manufacturing and Other Business Activity
# 5904  201510          St Louis                 Real Estate and Construction
# 5905  201510          St Louis            Agriculture and Natural Resources
# 5906  201510          St Louis                    Overall Economic Activity
# 5907  201510          St Louis                            Consumer Spending
# 5908  201510          St Louis                          Banking and Finance
#
#                                             Description
# 5813  \nConsumer spending grew at a moderate pace ov...
# 5814  \nLabor markets generally tightened since the ...
# 5815  Reports from the twelve Federal Reserve Distri...
# 5816  \nNonfinancial services activity generally str...
# 5817  \nOn the whole, manufacturing conditions were ...
# 5818  \nResidential real estate activity has general...
# 5819  \nAgriculture conditions were mixed. Growing c...
# 5820  \nReports from the banking sector were general...
# 5821  \nDistrict contacts indicated that residential...
# 5822  \nDistrict manufacturers indicated that busine...
# 5823  \nReports indicated that credit remained readi...
# 5824  \nMany District companies continued to report ...
# 5825  \nContinued weak global demand and an oversupp...
# 5826  Sixth District business contacts described eco...
# 5827  \nDistrict retailers reported mixed activity f...
# 5828  \nOf 10 firms contacted this cycle, only one, ...
# 5829  \nRevenues are mostly up from a year earlier a...
# 5830  \nClosed sales of both single-family homes and...
# 5831  Business activity levels continue to increase ...
# 5832  \nRetailers consulted for this round report ye...
# 5833  \nConditions in the First District's commercia...
# 5834  \nGrowth in consumer spending slowed to a more...
# 5835  \nThe condition of the District's corn and soy...
# 5836  Growth in economic activity in the Seventh Dis...
# 5837  \nGrowth in business spending remained moderat...
# 5838  \n\nConstruction and real estate activity incr...
# 5839  \nManufacturing production growth slowed to a ...
# 5840  \nCost pressures remained subdued in late Augu...
# 5841  \n\nCredit conditions were little changed over...
# 5842  \nYear-to-date sales through August of new and...
# ...                                                 ...
# 5879  \nThe labor market has shown further signs of ...
# 5880  \nRetail sales continued at a moderate pace. A...
# 5881  \nThird District financial firms have reported...
# 5882  \nOverall, Third District homebuilders have re...
# 5883  \nThird District service-sector firms reported...
# 5884  \nGeneral price levels have continued to rise ...
# 5885  Aggregate business activity in the Third Distr...
# 5886  \nDuring the latest Beige Book period, more co...
# 5887  \nManufacturing reports were mixed since the l...
# 5888  \nResidential real estate activity grew at a m...
# 5889  \nAgribusiness reported modest revenue growth ...
# 5890  \nSince the last Beige Book, the demand for la...
# 5891  Information gathered since the last Beige Book...
# 5892  \nRetail sales grew at a slower pace since the...
# 5893  \nActivity at non-retail services firms was mi...
# 5894  \nLoan demand improved slightly, on balance, s...
# 5895  \nExports softened year-over-year in recent we...
# 5896  \nRetail sales grew at a moderate pace over th...
# 5897  \nManufacturing activity was mixed but appeare...
# 5898  \nAgricultural activity expanded slightly duri...
# 5899  \nReal estate activity picked up further. Cont...
# 5900  \nLending activity grew modestly over the repo...
# 5901  Economic activity in the District grew at a mo...
# 5902  \nOverall price inflation appeared to pick up ...
# 5903  \nManufacturing activity has improved at a mod...
# 5904  \nResidential real estate activity continued t...
# 5905  \nContacts expect District row crop yields to ...
# 5906  Employment, Wages, and Prices\nDistrict employ...
# 5907  \nAnecdotal evidence from local contacts indic...
# 5908  \nOverall banking conditions remain strong in ...
#
# [96 rows x 4 columns]

# %%
df_joined = df.join(df_categories.set_index('Sector'), on='Sector')

# %%
df_joined.loc[df_joined.Category.isnull(),'Category'] =\
    "Manufacturing, Services"

# %%
df_joined.loc[df_joined['District'] == 'St Louis', 'District'] = 'St. Louis'
df_joined.sort_values(['Date','District','Category','Sector'])
# Out:
#         Date       District                                       Sector  \
# 12    200801        Atlanta            Agriculture and Natural Resources
# 13    200801        Atlanta                    Overall Economic Activity
# 11    200801        Atlanta                        Employment and Prices
# 10    200801        Atlanta                          Banking and Finance
# 9     200801        Atlanta             Manufacturing and Transportation
# 8     200801        Atlanta                                  Real Estate
# 14    200801        Atlanta                Consumer Spending and Tourism
# 17    200801         Boston                    Overall Economic Activity
# 18    200801         Boston                                Manufacturing
# 19    200801         Boston                       Commercial Real Estate
# 16    200801         Boston                      Residential Real Estate
# 15    200801         Boston                                       Retail
# 21    200801        Chicago                                  Agriculture
# 22    200801        Chicago                    Overall Economic Activity
# 26    200801        Chicago                             Prices and Costs
# 27    200801        Chicago                          Banking and Finance
# 23    200801        Chicago                            Business spending
# 25    200801        Chicago                                Manufacturing
# 24    200801        Chicago                 Construction and Real Estate
# 20    200801        Chicago                            Consumer Spending
# 31    200801      Cleveland                                       Energy
# 33    200801      Cleveland                    Overall Economic Activity
# 30    200801      Cleveland                                      Banking
# 34    200801      Cleveland                                Manufacturing
# 32    200801      Cleveland                               Transportation
# 28    200801      Cleveland                                  Real Estate
# 29    200801      Cleveland                            Consumer Spending
# 39    200801         Dallas                                  Agriculture
# 38    200801         Dallas                                       Energy
# 44    200801         Dallas                    Overall Economic Activity
# ...      ...            ...                                          ...
# 7298  201707   Philadelphia                        Nonfinancial Services
# 7292  201707   Philadelphia                 Real Estate and Construction
# 7296  201707   Philadelphia                            Consumer Spending
# 7303  201707       Richmond            Agriculture and Natural Resources
# 7308  201707       Richmond                 Summary of Economic Activity
# 7299  201707       Richmond                         Employment and Wages
# 7304  201707       Richmond                                       Prices
# 7301  201707       Richmond                          Banking and Finance
# 7305  201707       Richmond                                Manufacturing
# 7302  201707       Richmond                       Non-Financial Services
# 7306  201707       Richmond                     Ports and Transportation
# 7300  201707       Richmond                 Real Estate and Construction
# 7307  201707       Richmond                  Retail, Travel, and Tourism
# 7316  201707  San Francisco  Agriculture and Resource-Related Industries
# 7311  201707  San Francisco                 Summary of Economic Activity
# 7309  201707  San Francisco                         Employment and Wages
# 7312  201707  San Francisco                                       Prices
# 7310  201707  San Francisco                       Financial Institutions
# 7314  201707  San Francisco                                Manufacturing
# 7315  201707  San Francisco                 Real Estate and Construction
# 7313  201707  San Francisco                    Retail Trade and Services
# 7320  201707      St. Louis            Agriculture and Natural Resources
# 7321  201707      St. Louis                 Summary of Economic Activity
# 7317  201707      St. Louis                         Employment and Wages
# 7325  201707      St. Louis                                       Prices
# 7319  201707      St. Louis                          Banking and Finance
# 7323  201707      St. Louis                                Manufacturing
# 7324  201707      St. Louis                        Nonfinancial Services
# 7318  201707      St. Louis                 Real Estate and Construction
# 7322  201707      St. Louis                            Consumer Spending
#
#                                             Description  \
# 12    \nRains during December brought short-term rel...
# 13    Reports from contacts for late November throug...
# 11    \nThe demand for workers in some sectors conti...
# 10    \nFinancial industry contacts reported reduced...
# 9     \nManufacturing activity varied by industry.  ...
# 8     \nHomebuilders and Realtors reported that new ...
# 14    \nMost retail contacts reported that holiday s...
# 17    Closing out 2007 with mixed results, business ...
# 18    \nManufacturers and related services  provider...
# 19    \nThe common theme of respondents this time is...
# 16    \nNew England residential real estate markets ...
# 15    \nFirst District retailers report mixed  sales...
# 21    \nDuring the reporting period, in nominal term...
# 22    Economic activity in the Seventh District cont...
# 26    \nManufacturers indicated that input costs ros...
# 27    \nCredit market conditions remained tight in D...
# 23    \nOverall, the pace of business spending was l...
# 25    \nManufacturing growth was relatively stable c...
# 24    \nResidential construction and home sales in t...
# 20    \nConsumer spending continued to be mixed, wit...
# 31    \nOil and gas production has been steady to in...
# 33    Economic activity in the Fourth District expan...
# 30    \nA majority of bankers described business and...
# 34    \nIn general, manufacturing output has been st...
# 32    \nTrucking executives characterized freight vo...
# 28    \nMost home builders reported very weak sales ...
# 29    \nOverall sales by District retailers were fla...
# 39    \nDomestic and global demand remained strong. ...
# 38    \nGlobal demand for energy remained strong. Th...
# 44    The pace of economic activity in the Eleventh ...
# ...                                                 ...
# 7298  \nService-sector firms continued to report mod...
# 7292  \nHomebuilders generally reported a slight dec...
# 7296  \nNonauto retail contacts noted modest decline...
# 7303  \nReports on energy markets were somewhat posi...
# 7308  \n  The Fifth District economy expanded modest...
# 7299  \nLabor demand strengthened moderately in rece...
# 7304  \nIn general, prices were little changed to up...
# 7301  \nOn balance, loan demand continued to grow at...
# 7305  \nManufacturing firms reported modest increase...
# 7302  \nServices firms generally reported modest rev...
# 7306  \nSince our last report, freight volumes throu...
# 7300  \nResidential real estate sales increased mode...
# 7307  \nRetail sales increased in recent weeks, with...
# 7316  \nActivity in the agriculture sector picked up...
# 7311  \n  Economic activity in the Twelfth District ...
# 7309  \nOn balance, wage pressures ticked up, and co...
# 7312  \nOverall, price inflation was flat over the r...
# 7310  \nOn balance, conditions in the financial serv...
# 7314  \nConditions in the manufacturing sector impro...
# 7315  \nReal estate market activity picked up to a r...
# 7313  \nOn balance, retail sales were modest over th...
# 7320  \nAgricultural conditions improved modestly by...
# 7321  \n  Reports from contacts suggest economic con...
# 7317  \nAnecdotal evidence suggests employment is li...
# 7325  \nPrice pressures in the District remained mod...
# 7319  \nLending activity in the Eighth District has ...
# 7323  \nManufacturing activity has increased modestl...
# 7324  \nReports of plans in the service sector have ...
# 7318  \nResidential real estate activity has decline...
# 7322  \nReports from general retailers, auto dealers...
#
#                                     Category
# 12    Agriculture, Energy, Natural Resources
# 13                                   Economy
# 11                 Employment, Prices, Wages
# 10                                   Finance
# 9                    Manufacturing, Services
# 8                  Real Estate, Construction
# 14                 Retail, Consumer Spending
# 17                                   Economy
# 18                   Manufacturing, Services
# 19                 Real Estate, Construction
# 16                 Real Estate, Construction
# 15                 Retail, Consumer Spending
# 21    Agriculture, Energy, Natural Resources
# 22                                   Economy
# 26                 Employment, Prices, Wages
# 27                                   Finance
# 23                   Manufacturing, Services
# 25                   Manufacturing, Services
# 24                 Real Estate, Construction
# 20                 Retail, Consumer Spending
# 31    Agriculture, Energy, Natural Resources
# 33                                   Economy
# 30                                   Finance
# 34                   Manufacturing, Services
# 32                   Manufacturing, Services
# 28                 Real Estate, Construction
# 29                 Retail, Consumer Spending
# 39    Agriculture, Energy, Natural Resources
# 38    Agriculture, Energy, Natural Resources
# 44                                   Economy
# ...                                      ...
# 7298                 Manufacturing, Services
# 7292               Real Estate, Construction
# 7296               Retail, Consumer Spending
# 7303  Agriculture, Energy, Natural Resources
# 7308                                 Economy
# 7299               Employment, Prices, Wages
# 7304               Employment, Prices, Wages
# 7301                                 Finance
# 7305                 Manufacturing, Services
# 7302                 Manufacturing, Services
# 7306                 Manufacturing, Services
# 7300               Real Estate, Construction
# 7307               Retail, Consumer Spending
# 7316  Agriculture, Energy, Natural Resources
# 7311                                 Economy
# 7309               Employment, Prices, Wages
# 7312               Employment, Prices, Wages
# 7310                                 Finance
# 7314                 Manufacturing, Services
# 7315               Real Estate, Construction
# 7313               Retail, Consumer Spending
# 7320  Agriculture, Energy, Natural Resources
# 7321                                 Economy
# 7317               Employment, Prices, Wages
# 7325               Employment, Prices, Wages
# 7319                                 Finance
# 7323                 Manufacturing, Services
# 7324                 Manufacturing, Services
# 7318               Real Estate, Construction
# 7322               Retail, Consumer Spending
#
# [7606 rows x 5 columns]

# %%
df_joined.to_csv("fulltext.csv")
