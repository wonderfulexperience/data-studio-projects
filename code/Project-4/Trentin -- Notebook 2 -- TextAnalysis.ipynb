# %% [markdown]
# <b>Scraping and Analyzing Fed Beige Books</b><br>
# Project by Alexander Trentin<br>
# <br>
# Part 2: Analysis

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.feature_extraction.text import CountVectorizer 
from textblob import TextBlob

# %matplotlib inline

# %%
#import the file which was created in Notebook 1 
df_original = pd.read_csv('fulltext.csv')

# %%
#The sectors are obsolete, as they are mapped now to general categories
#The descriptions should be combined for each category
#To do that, a 
df = df_original.groupby(['Date','District','Category'])['Description']\
    .apply(lambda x: " ".join(x))
df = df.reset_index()

# %%
#get rid of periods to separate sentences later easier
df.Description = df.Description.str.replace("U.S.","US")
df.Description = df.Description.str.replace("D.C.","DC")
df.Description = df.Description.str.replace("St.","St")
df.Description = df.Description.str.replace("Va.","Va")
df.Description = df.Description.str.replace("N.C.","NC")
df.Description = df.Description.str.replace("W.","W")
df.Description = df.Description.str.replace("S.C.","SC")
df.Description = df.Description.str.replace("S.D.","SD")
df.Description = df.Description.str.replace("Md.","Md")
df.Description = df.Description.str.replace(r"[0-9](\.)[0-9]",r",")

# %% [markdown]
# Text Analysis<br>
# - use sklearn to get the most frequent phrases
# - use a manual mapping file if a phrase is positive or negative, if it contains an adjective

# %%
#Add adverbs and adjectives into one dataframe
adverbs = pd.read_csv('conv.data.adv',index_col=False,names=['word'])
adjectives = pd.read_csv('conv.data.adj',index_col=False,names=['word'])

frames = [adverbs, adjectives]

adjectives = pd.concat(frames)
list_adjectives = list(adjectives.word)

# %%
def textblob_tokenizer(str_input):
    blob = TextBlob(str_input.lower())
    words = blob.words
    return words

# %%
stop_words = ["the","district","was","were","next","previous","of","according"
              "beige","first","second","third","sector","since","our",
             "reported","noted","and","reports","reporting","period","over","outlook","york",
             "francisco","january","kansas","dallas","in","from","during","districts",
             "demand","commercial","for","contacts","continued",
             "compared","boston","a","as","at","activity","sector","ago","year","february","march","month",
             "creighton","recent","atlanta","chicago","ny","nj","louis","pa","managers",
             "university","omaha","to","months","report","minneapolis","indicated","that","according",
             "'s","one","two","three","four","five","six","seven","eight","nine","ten","which","percent",
             "survey","richmond","is","by","philadelphia","cleveland","20","7","major","year-to-date","this",
             "announced","on","eighth","cents","an","are","although","did","jersey","england","city",
             "year-ago", "dakota", "south", "carolina", "or", "but", "general", "generally", "may",
             "july","october","twelve","virginia","overall","siena","college","most",'been','year-over-year',
             'all','across','except','particularly','book']

vec = CountVectorizer(stop_words=stop_words, tokenizer = textblob_tokenizer, ngram_range=(2,2), min_df=90)

matrix = vec.fit_transform(df.Description)

results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
print(results.shape)
list_words = list(vec.get_feature_names())
# Out:
# (6195, 523)

# %%
vec = CountVectorizer(stop_words=stop_words, tokenizer = textblob_tokenizer, ngram_range=(3,3), min_df=23)

matrix = vec.fit_transform(df.Description)

results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
print(results.shape)
list_words = list_words + list(vec.get_feature_names())
# Out:
# (6136, 802)

# %%
vec = CountVectorizer(stop_words=stop_words, tokenizer = textblob_tokenizer, ngram_range=(4,4), min_df=13)

matrix = vec.fit_transform(df.Description)

results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
print(results.shape)
list_words = list_words + list(vec.get_feature_names())
# Out:
# (6136, 591)

# %%
vec = CountVectorizer(stop_words=stop_words, tokenizer = textblob_tokenizer, ngram_range=(5,5), min_df=8)

matrix = vec.fit_transform(df.Description)

results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
print(results.shape)
list_words = list_words + list(vec.get_feature_names())
# Out:
# (6136, 682)

# %%
list_words = set(list_words)
list_relevant = []
for word in list_words:
    for adjective in list_adjectives:
        for this_word in word.split(" "):
            if adjective == this_word:
                list_relevant.append(word)

# %%
mapping = pd.read_csv("map_adjectives.csv")

# %%
vocab_list = list(mapping.adjective)
#count words according to updated adjective list
vec = CountVectorizer(stop_words=stop_words, tokenizer = textblob_tokenizer, ngram_range=(1,3), vocabulary=vocab_list)

matrix = vec.fit_transform(df.Description)

results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
print(results.shape)
# Out:
# (6195, 105)

# %%
veryNegativeList = list(mapping[mapping.score == -2].adjective)
negativeList = list(mapping[mapping.score == -1].adjective)
neutralList = list(mapping[mapping.score == 0].adjective)
positiveList = list(mapping[mapping.score == 1].adjective)
veryPositiveList = list(mapping[mapping.score == 2].adjective)

# %%
df['veryNegative'] = results[veryNegativeList].sum(axis=1)
df['negative'] = results[negativeList].sum(axis=1)
df['neutral'] = results[neutralList].sum(axis=1)
df['positive'] = results[positiveList].sum(axis=1)
df['veryPositive'] = results[veryPositiveList].sum(axis=1)

# %%
# add for each combination of Date, District and Category
# the most important phrases and the economc sentiment

def compare_phrases(row):
    
    adjective_score = row['veryNegative'] * (-2) + row['negative'] * (-1) + row['positive']*1 + row['veryPositive'] * 2
    adjective_score_counter = row['veryNegative'] + row['negative'] + row ['neutral'] + row['positive'] + row['veryPositive']
    
    if adjective_score_counter > 0:
        adjective_score = adjective_score / adjective_score_counter
    else:
        adjective_score = np.nan
    
    this_description = row['Description']

    #split up the descriptions by sentences
    this_description_sentences = this_description.split('.')
    
    #the maximum proportion of adjectives found in a phrase
    description_score_max = 0
    
    #this variable will be later filled with the most expressive sentence
    important_sentence = ""

    #Each sentence in the description is split up into words

    #Check if a word is in the adjective mapping table
    #Count how many words are in each sentence
    
    for description in this_description_sentences:
        description_words = description.split(' ')
        len_description = len(description_words)
        
        description_score = 0
        
        for adjective in list(mapping.adjective):
            if adjective in description:
                description_score += 1
        
        description_score = description_score / len_description
        
        
        #Check if the sentence has the highest score regarding adjectives
        #If it has the highest, it is for the time being the most important sentence
                
        if description_score > description_score_max:
            description_score_max = description_score
            important_sentence = description

  
    # return the sentiment score and the most important sentence
    
    return pd.Series({
        'adjective_score' : adjective_score,
        'important_phrase' : important_sentence
    })

# %%
df_new = df[['Date','District','Category']]
df_new = df.apply(compare_phrases, axis=1).join(df_new)

# %%
df_new
# Out:
#       adjective_score                                   important_phrase  \
# 0           -1.000000  \nGulf Coast crude oil inventories declined fu...
# 1           -0.500000    Manufacturing varied by industry, with defen...
# 2            0.800000    Input costs continue to increase for goods o...
# 3           -0.200000    Credit card lending was a notable exception ...
# 4            0.666667    However, producers of residential housing-re...
# 5           -0.600000    Residential construction was significantly b...
# 6            1.000000  \nReports concerning tourism continued to be q...
# 7           -0.428571  Closing out 2007 with mixed results, business ...
# 8            1.000000   Sales of aircraft equipment and pharmaceutica...
# 9           -0.086957  \nIn most markets and sectors, rents  and vaca...
# 10           0.000000  \nInventory levels are mixed, but  several con...
# 11          -1.000000   Hog prices rebounded, but were still below th...
# 12           0.200000    Residential construction continued to declin...
# 13           0.200000    The slowdown in construction led to further ...
# 14           0.000000    However, uncertainty concerning economic con...
# 15           0.200000    Labor market conditions softened slightly in...
# 16          -0.111111    Nonresidential rents were steady or down sli...
# 17          -0.428571  \nConsumer spending continued to be mixed, wit...
# 18           0.142857  \nOil and gas production has been steady to in...
# 19           0.200000  Economic activity in the Fourth District expan...
# 20           0.000000    The residential mortgage market remains very...
# 21           0.190476                        \nStel shipments were mixed
# 22           0.090909    Concerns about labor costs were limited to i...
# 23           0.000000    Vendor prices were steady to increasing duri...
# 24           1.000000                            Crop yields were steady
# 25           1.000000   Service sector activity has slowed some but i...
# 26           0.500000                           \nLabor markets softened
# 27          -0.714286   Respondents say consumer demand has softened ...
# 28           1.095238  \nDemand for plastics and petrochemicals has s...
# 29           0.400000   Traffic was slower than usual in December, an...
# ...               ...                                                ...
# 6165         0.785714   \nBusinesses in most service industries repor...
# 6166         0.450000  \nCommercial real estate markets have been mix...
# 6167         0.400000   Inventories were generally at or below normal...
# 6168         0.555556   However, auto sales and construction activity...
# 6169        -0.076923  \nEmployment has continued at a modest pace of...
# 6170         0.333333  \nFinancial firms reported slight growth of ov...
# 6171         0.400000   \nService-sector firms continued to report mo...
# 6172         0.125000  \nHomebuilders generally reported a slight dec...
# 6173         0.333333  \nNonauto retail contacts noted modest decline...
# 6174         0.333333   Coal production was little changed in recent ...
# 6175         0.789474   Manufacturers' shipments increased but new or...
# 6176         0.866667       Wge increases remained modest for most firms
# 6177         0.545455   Residential mortgage demand remained solid wh...
# 6178         1.142857      Demand for self-storage units rose moderately
# 6179         0.736842  \nResidential real estate sales increased mode...
# 6180         0.312500   Hardware and home improvement stores reported...
# 6181         0.750000  \nActivity in the agriculture sector picked up...
# 6182         1.166667   Conditions in the manufacturing sector improv...
# 6183         0.545455   Sluggish sales growth and rising compensation...
# 6184         0.285714   Deposits continued to increase but at a slowe...
# 6185         0.900000   Production of manufactured pharmaceuticals ex...
# 6186         1.142857   Financing conditions for commercial projects ...
# 6187         0.333333   Tourism demand remained strong, although cont...
# 6188         1.625000  \nAgricultural conditions improved modestly by...
# 6189         0.600000   Employers reported little hiring and moderate...
# 6190         0.400000  \nAcross the District, home prices continued t...
# 6191         1.300000   Commercial and industrial lending exhibited m...
# 6192         0.875000  \nManufacturing activity has increased modestl...
# 6193         0.625000  \nResidential real estate activity has decline...
# 6194         0.000000   Multiple auto dealers reported an increase in...
#
#         Date       District                                Category
# 0     200801        Atlanta  Agriculture, Energy, Natural Resources
# 1     200801        Atlanta                                 Economy
# 2     200801        Atlanta               Employment, Prices, Wages
# 3     200801        Atlanta                                 Finance
# 4     200801        Atlanta                 Manufacturing, Services
# 5     200801        Atlanta               Real Estate, Construction
# 6     200801        Atlanta               Retail, Consumer Spending
# 7     200801         Boston                                 Economy
# 8     200801         Boston                 Manufacturing, Services
# 9     200801         Boston               Real Estate, Construction
# 10    200801         Boston               Retail, Consumer Spending
# 11    200801        Chicago  Agriculture, Energy, Natural Resources
# 12    200801        Chicago                                 Economy
# 13    200801        Chicago               Employment, Prices, Wages
# 14    200801        Chicago                                 Finance
# 15    200801        Chicago                 Manufacturing, Services
# 16    200801        Chicago               Real Estate, Construction
# 17    200801        Chicago               Retail, Consumer Spending
# 18    200801      Cleveland  Agriculture, Energy, Natural Resources
# 19    200801      Cleveland                                 Economy
# 20    200801      Cleveland                                 Finance
# 21    200801      Cleveland                 Manufacturing, Services
# 22    200801      Cleveland               Real Estate, Construction
# 23    200801      Cleveland               Retail, Consumer Spending
# 24    200801         Dallas  Agriculture, Energy, Natural Resources
# 25    200801         Dallas                                 Economy
# 26    200801         Dallas               Employment, Prices, Wages
# 27    200801         Dallas                                 Finance
# 28    200801         Dallas                 Manufacturing, Services
# 29    200801         Dallas               Real Estate, Construction
# ...      ...            ...                                     ...
# 6165  201707       New York                 Manufacturing, Services
# 6166  201707       New York               Real Estate, Construction
# 6167  201707       New York               Retail, Consumer Spending
# 6168  201707   Philadelphia                                 Economy
# 6169  201707   Philadelphia               Employment, Prices, Wages
# 6170  201707   Philadelphia                                 Finance
# 6171  201707   Philadelphia                 Manufacturing, Services
# 6172  201707   Philadelphia               Real Estate, Construction
# 6173  201707   Philadelphia               Retail, Consumer Spending
# 6174  201707       Richmond  Agriculture, Energy, Natural Resources
# 6175  201707       Richmond                                 Economy
# 6176  201707       Richmond               Employment, Prices, Wages
# 6177  201707       Richmond                                 Finance
# 6178  201707       Richmond                 Manufacturing, Services
# 6179  201707       Richmond               Real Estate, Construction
# 6180  201707       Richmond               Retail, Consumer Spending
# 6181  201707  San Francisco  Agriculture, Energy, Natural Resources
# 6182  201707  San Francisco                                 Economy
# 6183  201707  San Francisco               Employment, Prices, Wages
# 6184  201707  San Francisco                                 Finance
# 6185  201707  San Francisco                 Manufacturing, Services
# 6186  201707  San Francisco               Real Estate, Construction
# 6187  201707  San Francisco               Retail, Consumer Spending
# 6188  201707      St. Louis  Agriculture, Energy, Natural Resources
# 6189  201707      St. Louis                                 Economy
# 6190  201707      St. Louis               Employment, Prices, Wages
# 6191  201707      St. Louis                                 Finance
# 6192  201707      St. Louis                 Manufacturing, Services
# 6193  201707      St. Louis               Real Estate, Construction
# 6194  201707      St. Louis               Retail, Consumer Spending
#
# [6195 rows x 5 columns]

# %%
#remove white space in "important phrases"
df_new['important_phrase'] = df_new['important_phrase'].astype(str).str.strip()

# %%
#add a column color according to the sentiment (adjective score)
#starting from very positive until very negative
df_new['color'] = '#0571b0'
df_new.loc[df_new['adjective_score']<1, 'color'] = '#92c5de'
df_new.loc[df_new['adjective_score']<0.4, 'color'] = '#B8B8B8'
df_new.loc[df_new['adjective_score']<-0.3, 'color'] = '#f4a582'
df_new.loc[df_new['adjective_score']<-0.9, 'color'] = '#ca0020'

# %%
#mapping dictionary from the district names to codes used in the URL
report_districts = {
    "National Summary":"su",
    "Atlanta":"at",
    "Boston":"bo",
    "Chicago":"ch",
    "Cleveland":"cl",
    "Dallas":"da",
    "Kansas City":"kc",
    "Minneapolis":"mi",
    "New York":"ny",
    "Philadelphia":"ph",
    "Richmond":"ri",
    "San Francisco":"sf",
    "St. Louis":"sl"
}

# %%
#Create an URL column out of the date and the district code
#Later to be used as a link in the map
def getURLreport(row):
    this_date = str(row['Date'])[0:4]+"-"+str(row['Date'])[4:6]
    this_district = report_districts[row['District']]
    this_URL = "https://www.minneapolisfed.org/news-and-events/beige-book-archive/"+this_date+"-"+this_district
    return pd.Series({'link_URL':this_URL})

df_new = df_new.apply(getURLreport, axis=1).join(df_new)

# %%
report_dates = [
"200801",
"200803",
"200804",
"200806",
"200807",
"200809",
"200810",
"200812",
"200901",
"200903",
"200904",
"200906",
"200907",
"200909",
"200910",
"200912",
"201001",
"201003",
"201004",
"201006",
"201007",
"201009",
"201010",
"201012",
"201101",
"201103",
"201104",
"201106",
"201107",
"201109",
"201110",
"201111",
"201201",
"201202",
"201204",
"201206",
"201207",
"201208",
"201210",
"201211",
"201301",
"201303",
"201304",
"201306",
"201307",
"201309",
"201310",
"201312",
"201401",
"201403",
"201404",
"201406",
"201407",
"201409",
"201410",
"201412",
"201501",
"201503",
"201504",
"201506",
"201509",
"201510",
"201512",
"201601",
"201603",
"201604",
"201606",
"201607",
"201609",
"201610",
"201611",
"201701",
"201703",
"201704",
"201705",
"201707"
]
for report_date in report_dates:
    df_new[df_new.Date == int(report_date)].to_csv('data_'+report_date+'.csv', index=False)
